# %% [markdown]
# Aquí se comparan todos los modelos utilizados

# %% [markdown]
# import glob
# dfs = [pd.read_csv(f) for f in glob.glob('../reports/*_metrics.csv')]
# comparison = pd.concat(dfs).sort_values('RMSE')
