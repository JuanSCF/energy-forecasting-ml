# %%
import torch
import platform
import subprocess

# CPU
print(f"CPU: {platform.processor()}")

# RAM
import psutil
ram = psutil.virtual_memory()
print(f"RAM total : {ram.total / 1e9:.1f} GB")
print(f"RAM libre : {ram.available / 1e9:.1f} GB")

# GPU
print(f"\nCUDA disponible : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU             : {torch.cuda.get_device_name(0)}")
    print(f"VRAM total      : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("No hay GPU disponible para PyTorch")
# Out:
# CPU: AMD64 Family 23 Model 96 Stepping 1, AuthenticAMD
# RAM total : 7.9 GB
# RAM libre : 0.9 GB
#
# CUDA disponible : True
# GPU             : NVIDIA GeForce GTX 1650 Ti
# VRAM total      : 4.3 GB

# %%
import torch
print(torch.cuda.is_available())        # debe ser True
print(torch.cuda.get_device_name(0))    # debe ser "NVIDIA GeForce GTX 1650 Ti"
print(torch.cuda.get_device_properties(0).total_memory / 1e9)  # debe ser ~4.0 GB
# Out:
# True
# NVIDIA GeForce GTX 1650 Ti
# 4.294639616
